# %%
Mjj_selection = 1000.

vae_loss = 'mae'

SM_eff = 1e-2

def computeDiscriminatingVar(x):
    out = x[:,-2]/x[:,1]+x[:,-1]/x[:,6]
    out *= 1e5
    return out

# def computeDiscriminatingVar(x):
#     out = x[:,-2]+x[:,-1]
#     return out*1e4

# %% [markdown]
# # Imports

# %%
from __future__ import print_function

import h5py, os, sys, glob, datetime, time
sys.path.append('../lib')
from glob import glob
import numpy as np
import scipy as sp
from scipy.special import erf

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 18})
from matplotlib.colors import LogNorm

from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import joblib
from prettytable import PrettyTable

import ROOT as rt
rt.gErrorIgnoreLevel = rt.kError

from histo_utilities import create_TH2D, create_TH1D, create_Canvas, make_effiency_plot, rootTH1_to_np
from progressBar import ProgressBar

from cebefo_style import cebefo_style
cebefo_style()

dnd = []
# Out:
# Welcome to JupyROOT 6.16/00

# %% [markdown]
# # Get the discrimination on the side-band

# %%
f = h5py.File('../data/vae_'+vae_loss+'/qcd_dEta_sideband_results.h5', 'r')
print(list(f.get("labels")))

data_side = np.array(f.get("results"))

# apply the dijet mass cut
data_side = data_side[data_side[:,0] > Mjj_selection]
print(data_side.shape)

c = create_Canvas(size=(int(800/1.5),int(600/1.5)))
h_Mjj_side = create_TH1D(data_side[:,0], title='', axis_title = ['M_{jj} [GeV]','Events'], 
                opt='overflow', 
                binning=[100, Mjj_selection, np.max(data_side[:,0])])

h_Mjj_side.Draw()
c.SetLogy()
c.Draw()
# Out:
# ['mJJ', 'j1Pt', 'j1Eta', 'j1Phi', 'j1M', 'j1E', 'j2Pt', 'j2M', 'j2E', 'DeltaEtaJJ', 'DeltaPhiJJ', 'j1Loss', 'j2Loss']
# (38568, 13)

# %% [markdown]
# ### Train the model to predict the cut

# %%
gbr_cut = GradientBoostingRegressor(loss='quantile', alpha=1-SM_eff,
                                n_estimators=250, max_depth=3,
                                learning_rate=.1, min_samples_leaf=5,
                                min_samples_split=5,
                                validation_fraction=0.5,
                                n_iter_no_change=5,
                                tol=1e-5,
                                verbose=2)

x = np.reshape(data_side[:,0], (-1,1))
y = computeDiscriminatingVar(data_side)
gbr_cut.fit(x, y);

date = datetime.date.today()
date_str = '{}{:02d}{:02d}'.format(date.year, date.month, date.day)
joblib.dump(gbr_cut, '../models/gbr_cut_trained_{}.joblib'.format(date_str))
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.3824            2.50s
#          2           0.3820            3.30s
#          3           0.3816            2.94s
#          4           0.3812            2.85s
#          5           0.3809            2.62s
#          6           0.3806            2.41s
#          7           0.3804            2.31s
#          8           0.3802            2.16s
#          9           0.3801            2.09s
#         10           0.3800            1.99s
#         11           0.3799            1.91s
# ['../models/gbr_cut_trained_20190731.joblib']

# %%
plt.figure(figsize=(8, 8))
x_min = Mjj_selection*0.8
x_max = np.quantile(x, 0.999)
plt.hist2d(x[:,0], y,
           range=((x_min , x_max), (np.min(y), np.quantile(y, 1-1e-4))), 
           norm=LogNorm(), bins=100,
           label='Side band data'
          )

xs = np.arange(Mjj_selection, x_max, 0.001*(x_max-Mjj_selection))
plt.plot(xs, gbr_cut.predict(np.reshape(xs, (-1,1))), '-', color='m', lw=3, label='GBR selection')

plt.ylabel('$L_1/P^1_T + L_2/P^2_T$ [GeV^-1]')
plt.xlabel('$M_{jj}$ [GeV]')
plt.colorbar()
plt.legend(loc='best')
plt.draw()

# %%
def getSelection(x_Mjj, x_loss):
    cut = gbr_cut.predict(np.reshape(x_Mjj, (-1,1)))
    return x_loss > cut

# %%
def plotMassSpectrum(mJJ_pass, mJJ_rej, title=''):
    h_a = create_TH1D(mJJ_pass, 
                      name='h_acc', title='Accepted',
                      binning=binning,
                      opt='overflow'
                     )
    h_a.SetLineColor(2)
    h_a.SetStats(0)
    h_a.Sumw2()
    h_r = create_TH1D(mJJ_rej, 
                      name='h_rej', title='Rejected',
                      axis_title=['M_{jj} [GeV]', 'Events'],
                      binning=binning,
                      opt='overflow'
                     )
    h_r.GetYaxis().SetRangeUser(0.5, 1.2*h_r.GetMaximum())
    h_r.SetStats(0)
    h_r.Sumw2()

    c = make_effiency_plot([h_r, h_a], ratio_bounds=[1e-4, 0.2], draw_opt = 'E', title=title)
    c.pad1.SetLogy()
    c.pad2.SetLogy()

    c.pad2.cd()
    c.ln = rt.TLine(h_r.GetXaxis().GetXmin(), SM_eff, h_r.GetXaxis().GetXmax(), SM_eff)
    c.ln.SetLineWidth(2)
    c.ln.SetLineStyle(7)
    c.ln.SetLineColor(8)
    c.ln.DrawLine(h_r.GetXaxis().GetXmin(), SM_eff, h_r.GetXaxis().GetXmax(), SM_eff)

    c.Draw()
    return c

# %%
x = x.flatten()
binning=[50, Mjj_selection, np.quantile(x, 0.999)]

sel = getSelection(x, y)

c = plotMassSpectrum(x[sel], x[np.logical_not(sel)], 'QCD side-band')
h_a = c.h_list[1]
h_r = c.h_list[0]

# %% [markdown]
# # Define and test Hypotesis test

# %%
def HypotesisTets(h_a_bin_content, h_r_bin_content, eff, N_asymov = 10000, max_N_asymov = 1e8, show_hist=False):
    nu = eff*h_r_bin_content/(1-eff)

    probs_obs = sp.stats.poisson.pmf(h_a_bin_content.astype(np.int), nu)
    probs_obs = np.where(probs_obs < 1e-10, np.full_like(probs_obs, 1e-10), probs_obs)
    s_obs = np.sum(-np.log(probs_obs), axis=-1)
    print('S obs:', s_obs)

    N_worse = 0
    N_tot = 0
    loops = 0
    while N_worse < 25 and N_tot < max_N_asymov:
        loops += 1
        if loops > 1 and loops%10 == 0:
            print(N_tot, N_worse)
        if loops == 10:
            print('Increasing by a factor 5 the number of asymov per loop')
            N_asymov *=5
        o_asymov = np.random.poisson(nu, (N_asymov, nu.shape[0]))
        probs = sp.stats.poisson.pmf(o_asymov, nu)
        probs = np.where(probs < 1e-10, np.full_like(probs, 1e-10), probs)
        nll = -np.log(probs)
        s_asymov = np.sum(nll, axis=-1)

        N_worse += np.sum(s_asymov > s_obs)
        N_tot += N_asymov

        if max_N_asymov/N_tot < 25 and (N_worse * (max_N_asymov/N_tot) < 25):
            print('Will never have enough stat - giving up.')
            p_val = max(1, N_worse)/float(N_tot)
            return p_val

    print('Test stat reached after {} loops'.format(loops))

    p_val = max(1, N_worse)/float(N_tot)
    
    if show_hist:
        plt.figure()
        binContent, _, _ = plt.hist(s_asymov, label='Distribution assuming eff={:.1f}%'.format(100*eff))
        plt.plot([s_obs, s_obs], [0,np.max(binContent)], label='Observed')
        plt.legend(loc='best')
        plt.xlabel('Test statistic')
        plt.ylabel('Entries')

    return p_val

# %%
h_a_bin_content, _ = rootTH1_to_np(h_a)
h_r_bin_content, _ = rootTH1_to_np(h_r)
HypotesisTets(h_a_bin_content, h_r_bin_content, SM_eff, N_asymov=10000)
# Out:
# S obs: 69.7846363171145
# Test stat reached after 1 loops
# 0.8962

# %% [markdown]
# # Analyze signal region

# %%
sample_loc = {'qcd':'qcd_dEta_signalregion_results.h5',
              'AtoZZZ':'AtoHZ_to_ZZZ_13TeV_PU40_results.h5',
              'GtoWW':'RSGraviton_WW_NARROW_13TeV_PU40_results.h5',
              'GtoBtt':'RSGraviton_tt_BROAD_13TeV_PU40_results.h5',
              'GtoNtt':'RSGraviton_tt_NARROW_13TeV_PU40_results.h5'
             }

sample_label = {'qcd':r'QCD',
                'AtoZZZ':r'$A\to ZZZ$',
                'GtoWW':r'$G\to WW$',
                'GtoBtt':r'$G_{B}\to t\bar{t}$',
                'GtoNtt':r'$G_{N}\to t\bar{t}$'
               }

sample_label_ROOT = {'qcd':'QCD',
                'AtoZZZ':'$A #rightarrow ZZZ',
                'GtoWW':'G #rightarrow WW',
                'GtoBtt':'G_{B} #rightarrow t#bar{t}',
                'GtoNtt':'G_{N} #rightarrow t#bar{t}'
               }

SM_samples = ['qcd']
BSM_samples = ['AtoZZZ', 'GtoWW', 'GtoBtt', 'GtoNtt']

sample_nGenEvts = {'qcd': 418*10000,
                   'AtoZZZ': 100*1000,
                   'GtoWW': 100*1000,
                   'GtoBtt': 96*1000,
                   'GtoNtt': 96*1000
                  }

sample_xsec = {'qcd': 8734.0 #pb
              }

# %% [markdown]
# ### Get the data

# %%
data = {}
sample_eff = {}
table = PrettyTable()
table.field_names = ['Sample', 'Trg evts', 'Eff. trg [%]', 'VAE sel. evts', 'Eff VAE [%]']

for n, fname in sample_loc.iteritems():
    f = h5py.File('../data/vae_'+vae_loss+'/'+fname, 'r')
    x = np.array(f.get("results"))

    # apply the dijet mass cut
    sel_Mjj = x[:,0] > Mjj_selection
    x = x[sel_Mjj]
    dVar = computeDiscriminatingVar(x)
    sel = getSelection(x[:,0], dVar)
    x = np.column_stack((x, dVar, sel))
    
    sample_eff[n] = float(x.shape[0])/sample_nGenEvts[n]
    
    dt = [(str(s), '<f4') for s in list(f.get("labels")) + ['dVar']]
    dt += [('sel', '?')]
    data[n] = np.array(list(zip(*x.T)), dtype=dt)
    
    eff = '{:.2f}'.format(100*np.sum(data[n]['sel'])/float(data[n]['sel'].shape[0]))
    table.add_row([n, data[n]['sel'].shape[0], '{:.1f}'.format(100*sample_eff[n]), np.sum(data[n]['sel']), eff])
    
print(table)
# Out:
# +--------+----------+--------------+---------------+-------------+
# | Sample | Trg evts | Eff. trg [%] | VAE sel. evts | Eff VAE [%] |
# +--------+----------+--------------+---------------+-------------+
# | GtoBtt |  65082   |     67.8     |     10168     |    15.62    |
# | GtoWW  |  52408   |     52.4     |     11271     |    21.51    |
# | GtoNtt |  63748   |     66.4     |     10217     |    16.03    |
# | AtoZZZ |  63490   |     63.5     |     11229     |    17.69    |
# |  qcd   |  86911   |     2.1      |      847      |     0.97    |
# +--------+----------+--------------+---------------+-------------+

# %% [markdown]
# ### Define utilitities

# %%
def plotMassSpectrum_wSig(h_r, h_a, h_a_sig, name_BSM, lumi_text, p_val):
    h_r.GetYaxis().SetRangeUser(0.5, 1.2*h_r.GetMaximum())
    h_r.SetStats(0)
    h_r.Sumw2()
    h_r.SetLineWidth(2)
    
    h_a.SetLineColor(2)
    h_a.SetStats(0)
    h_a.Sumw2()
    h_a.SetLineWidth(2)
    
    h_a_sig.SetFillStyle(3001)
    h_a_sig.SetFillColor(8)
    h_a_sig.SetLineWidth(0)

    c = make_effiency_plot([h_r, h_a], ratio_bounds=[1e-3, None], draw_opt = 'E')
    c.pad1.SetLogy()
    c.pad1.cd()
    h_a_sig.Draw('SAME')
    c.leg.AddEntry(h_a_sig, 'Acc. '+sample_label_ROOT[name_BSM], 'f')
    
    latex = rt.TLatex()
    latex.SetNDC()
    latex.SetTextSize(0.04)
    latex.SetTextAlign(31)
    t = c.pad1.GetTopMargin()
    r = c.pad1.GetRightMargin()
    latex.DrawLatex(1-r, 1-0.85*t, lumi_text)

    c.pad2.SetLogy()
    c.pad2.cd()
    c.ln = rt.TLine(h_r.GetXaxis().GetXmin(), SM_eff, h_r.GetXaxis().GetXmax(), SM_eff)
    c.ln.SetLineWidth(2)
    c.ln.SetLineStyle(7)
    c.ln.SetLineColor(6)
    c.ln.DrawLine(h_r.GetXaxis().GetXmin(), SM_eff, h_r.GetXaxis().GetXmax(), SM_eff)
    
    latex.SetTextSize(0.1)
    latex.SetTextAlign(13)
    l = c.pad2.GetLeftMargin()
    t = c.pad2.GetTopMargin()
    latex.DrawLatex(l*1.1, 1-2*t, 'p-value: {:.1f}%'.format(100*p_val))

    c.Draw()
    return c

# %% [markdown]
# ## Find the p-value as a function of xsec

# %%
lumi = 100 #pb^-1

N_asymov = 10000
# N_asymov = int(1 / (1 - erf(5.5/np.sqrt(2))))
N_exp_per_xsec = 100

# %%
dic_p_val = {}
rt.gROOT.SetBatch(True)

# %%
for name_BSM in BSM_samples[:2]:
    print('\n\n'+name_BSM)
    dic_p_val[name_BSM] = []
    for xsec_BSM in np.logspace(-1, 1, 7): 
        print('xsec BSM {:.1e} pb'.format(xsec_BSM))
        lumi_text = '{:.1f} fb^{{-1}} (14 TeV), '.format(1e-3*lumi) + sample_label_ROOT[name_BSM] + ' ({:.2} pb)'.format(xsec_BSM)

        p_val_test = []
        for i_exp in range(N_exp_per_xsec):
            print('Experiment:', i_exp)
            d_obs = np.zeros((0,2))

            sample_xsec[name_BSM] = xsec_BSM
            for n in SM_samples + [name_BSM]:
                nExpEvts = lumi*sample_xsec[n]*sample_eff[n]
                nEvts = np.random.poisson(nExpEvts)
                if data[n]['mJJ'].shape[0] < nEvts:
                    print('[WARNING] ' + n + ' re-use factor = {:.2f}'.format(float(nEvts)/data[n]['mJJ'].shape[0]))
                evtsIdx = np.random.randint(0, data[n]['mJJ'].shape[0], size=(nEvts,))

                d_aux = np.column_stack((data[n]['mJJ'][evtsIdx], data[n]['sel'][evtsIdx]))
                d_obs = np.concatenate((d_obs, d_aux))

            h_a = create_TH1D(d_obs[:, 0][d_obs[:,1].astype(np.bool)], 
                                 name='h_acc', title='Accepted',
                                 binning=binning,
                                 opt='overflow'
                                )

            h_r = create_TH1D(d_obs[:, 0][np.logical_not(d_obs[:,1]).astype(np.bool)], 
                                 name='h_rej', title='Rejected',
                                 axis_title=['M_{jj} [GeV]', ''],
                                 binning=binning,
                                 opt='overflow'
                                )
            h_r.SetYTitle('Events / {:.0f} GeV'.format(h_r.GetBinWidth(1)))

            h_a_bin_content, _ = rootTH1_to_np(h_a)
            h_r_bin_content, _ = rootTH1_to_np(h_r)
            p_val = HypotesisTets(h_a_bin_content, h_r_bin_content, SM_eff, N_asymov = N_asymov, show_hist=False)
            p_val_test.append(p_val)

            if i_exp > 3 and np.max(p_val_test) == 0:
                break

            if i_exp == 0:
                h_a_sig = create_TH1D(d_obs[-nEvts-1:, 0][d_obs[-nEvts-1:, 1].astype(np.bool)], 
                                     name='h_acc', title='Accepted',
                                     binning=binning,
                                     opt='overflow'
                                    )
                c = plotMassSpectrum_wSig(h_r, h_a, h_a_sig, name_BSM, lumi_text, p_val)
                fig_name = '../fig/ModelIndependentAnalysis/massSpectrum/'
                fig_name += name_BSM + '{:1.2e}'.format(xsec_BSM) + 'pb' + '_L' + str(lumi) + 'pb-1_wEff'
                c.SaveAs(fig_name + '.png')

        aux = [xsec_BSM] + list(np.percentile(p_val_test, [2.5, 16, 50, 84, 97.5]))
        dic_p_val[name_BSM].append(aux)
# Out:
# AtoZZZ
# xsec BSM 1.0e-01 pb
# S obs: 63.23237307298719
# Test stat reached after 1 loops
# S obs: 61.78806704777282
# Test stat reached after 1 loops
# S obs: 57.950227797586905
# Test stat reached after 1 loops
# S obs: 59.482232581669116
# Test stat reached after 1 loops
# S obs: 60.90252302155487
# Test stat reached after 1 loops
# S obs: 60.76155749392736
# Test stat reached after 1 loops
# S obs: 63.10992964363138
# Test stat reached after 1 loops
# S obs: 59.01838668687749
# Test stat reached after 1 loops
# S obs: 59.94004283426643
# Test stat reached after 1 loops
# S obs: 55.228534152618586
# Test stat reached after 1 loops
# S obs: 57.90705869436419
# Test stat reached after 1 loops
# S obs: 69.40751376757704
# Test stat reached after 1 loops
# S obs: 62.22650635916499
# Test stat reached after 1 loops
# S obs: 64.50107628843372
# Test stat reached after 1 loops
# S obs: 56.42537716325217
# Test stat reached after 1 loops
# S obs: 67.77018498728758
# Test stat reached after 1 loops
# S obs: 70.42682284136897
# Test stat reached after 1 loops
# S obs: 51.08857773421144
# Test stat reached after 1 loops
# S obs: 54.32500800426689
# Test stat reached after 1 loops
# S obs: 56.470507495437495
# Test stat reached after 1 loops
# S obs: 61.44168331155751
# Test stat reached after 1 loops
# S obs: 59.060315608028425
# Test stat reached after 1 loops
# S obs: 69.94867965438225
# Test stat reached after 1 loops
# S obs: 67.06494613811789
# Test stat reached after 1 loops
# S obs: 64.76310376289872
# Test stat reached after 1 loops
# S obs: 54.46861703194039
# Test stat reached after 1 loops
# S obs: 59.96741979178925
# Test stat reached after 1 loops
# S obs: 63.70487041206913
# Test stat reached after 1 loops
# S obs: 59.5473917283711
# Test stat reached after 1 loops
# S obs: 59.7660792401657
# Test stat reached after 1 loops
# S obs: 62.97624815170354
# Test stat reached after 1 loops
# S obs: 71.006814854708
# Test stat reached after 1 loops
# S obs: 54.437883864925666
# Test stat reached after 1 loops
# S obs: 57.001250837336265
# Test stat reached after 1 loops
# S obs: 57.38963564261565
# Test stat reached after 1 loops
# S obs: 53.58767854735841
# Test stat reached after 1 loops
# S obs: 64.97289692542398
# Test stat reached after 1 loops
# S obs: 61.066866530116734
# Test stat reached after 1 loops
# S obs: 66.84015036256066
# Test stat reached after 1 loops
# S obs: 65.90711466884868
# Test stat reached after 1 loops
# S obs: 67.50763389798655
# Test stat reached after 1 loops
# S obs: 56.497022243335245
# Test stat reached after 1 loops
# S obs: 73.78279812926031
# Test stat reached after 1 loops
# S obs: 61.25375540103596
# Test stat reached after 1 loops
# S obs: 58.7118580629893
# Test stat reached after 1 loops
# S obs: 56.87125356137998
# Test stat reached after 1 loops
# S obs: 69.49856009965325
# Test stat reached after 1 loops
# S obs: 55.83194706191191
# Test stat reached after 1 loops
# S obs: 70.67649343434464
# Test stat reached after 1 loops
# S obs: 64.42853033022463
# Test stat reached after 1 loops
# S obs: 59.06926031467776
# Test stat reached after 1 loops
# S obs: 65.6747040242541
# Test stat reached after 1 loops
# S obs: 61.43387244547939
# Test stat reached after 1 loops
# S obs: 60.05695681404032
# Test stat reached after 1 loops
# S obs: 68.98292990729988
# Test stat reached after 1 loops
# S obs: 56.91223794620704
# Test stat reached after 1 loops
# S obs: 58.41078144061798
# Test stat reached after 1 loops
# S obs: 67.87887686936153
# Test stat reached after 1 loops
# S obs: 54.27543649201987
# Test stat reached after 1 loops
# S obs: 56.13790187816139
# Test stat reached after 1 loops
# S obs: 58.85095887800086
# Test stat reached after 1 loops
# S obs: 55.893489752538
# Test stat reached after 1 loops
# S obs: 64.94513665115197
# Test stat reached after 1 loops
# S obs: 74.19430023174245
# Test stat reached after 1 loops
# S obs: 54.711079078858084
# Test stat reached after 1 loops
# S obs: 60.38334453080565
# Test stat reached after 1 loops
# S obs: 53.61263503424863
# Test stat reached after 1 loops
# S obs: 61.8674142069058
# Test stat reached after 1 loops
# S obs: 62.922242494701955
# Test stat reached after 1 loops
# S obs: 75.2575726748287
# Test stat reached after 1 loops
# S obs: 62.26305540281608
# Test stat reached after 1 loops
# S obs: 56.42110184660138
# Test stat reached after 1 loops
# S obs: 59.40578397746132
# Test stat reached after 1 loops
# S obs: 52.14678285166851
# Test stat reached after 1 loops
# S obs: 67.33623097552595
# Test stat reached after 1 loops
# S obs: 61.07095512462314
# Test stat reached after 1 loops
# S obs: 61.65034580382468
# Test stat reached after 1 loops
# S obs: 67.36117765152962
# Test stat reached after 1 loops
# S obs: 62.603411460847795
# Test stat reached after 1 loops
# S obs: 60.18973966611865
# Test stat reached after 1 loops
# S obs: 61.69399355813547
# Test stat reached after 1 loops
# S obs: 57.72853072351924
# Test stat reached after 1 loops
# S obs: 69.7535124492565
# Test stat reached after 1 loops
# S obs: 65.07331636730143
# Test stat reached after 1 loops
# S obs: 55.84104189758307
# Test stat reached after 1 loops
# S obs: 57.73792082497197
# Test stat reached after 1 loops
# S obs: 74.9801748784946
# Test stat reached after 1 loops
# S obs: 64.9600545222823
# Test stat reached after 1 loops
# S obs: 63.165360646402696
# Test stat reached after 1 loops
# S obs: 57.555902241003764
# Test stat reached after 1 loops
# S obs: 57.958277162624555
# Test stat reached after 1 loops
# S obs: 64.80433991806072
# Test stat reached after 1 loops
# S obs: 62.028086073328446
# Test stat reached after 1 loops
# S obs: 56.87167027527129
# Test stat reached after 1 loops
# S obs: 59.712760347969805
# Test stat reached after 1 loops
# S obs: 54.49600340521762
# Test stat reached after 1 loops
# S obs: 69.04650306425975
# Test stat reached after 1 loops
# S obs: 62.26240454884745
# Test stat reached after 1 loops
# S obs: 71.72341509026646
# Test stat reached after 1 loops
# S obs: 57.54854432722219
# Test stat reached after 1 loops
# xsec BSM 2.2e-01 pb
# S obs: 65.3028179604625
# Test stat reached after 1 loops
# S obs: 69.20617835756232
# Test stat reached after 1 loops
# S obs: 61.15332165631546
# Test stat reached after 1 loops
# S obs: 66.29691365024924
# Test stat reached after 1 loops
# S obs: 56.86477606515596
# Test stat reached after 1 loops
# S obs: 57.87844022298035
# Test stat reached after 1 loops
# S obs: 58.585348174053344
# Test stat reached after 1 loops
# S obs: 63.6310174203545
# Test stat reached after 1 loops
# S obs: 55.031260952932676
# Test stat reached after 1 loops
# S obs: 58.80550100089062
# Test stat reached after 1 loops
# S obs: 61.08188698920557
# Test stat reached after 1 loops
# S obs: 62.46489486797409
# Test stat reached after 1 loops
# S obs: 56.47872124171482
# Test stat reached after 1 loops
# S obs: 54.59144301921152
# Test stat reached after 1 loops
# S obs: 74.47654936607415
# Test stat reached after 1 loops
# S obs: 69.13762676612441
# Test stat reached after 1 loops
# S obs: 69.01180532489376
# Test stat reached after 1 loops
# S obs: 60.7257594616444
# Test stat reached after 1 loops
# S obs: 58.93511669786346
# Test stat reached after 1 loops
# S obs: 56.76525132174127
# Test stat reached after 1 loops
# S obs: 67.11320176421208
# Test stat reached after 1 loops
# S obs: 64.73662285351907
# Test stat reached after 1 loops
# S obs: 61.712569012401694
# Test stat reached after 1 loops
# S obs: 66.52758811351383
# Test stat reached after 1 loops
# S obs: 69.879515863337
# Test stat reached after 1 loops
# S obs: 75.15709807226689
# Test stat reached after 1 loops
# S obs: 61.86773615557141
# Test stat reached after 1 loops
# S obs: 67.15512285103065
# Test stat reached after 1 loops
# S obs: 62.817757655018795
# Test stat reached after 1 loops
# S obs: 64.54247303872634
# Test stat reached after 1 loops
# S obs: 64.30615562859583
# Test stat reached after 1 loops
# S obs: 61.88317783503567
# Test stat reached after 1 loops
# S obs: 67.30532826965673
# Test stat reached after 1 loops
# S obs: 64.48338021823373
# Test stat reached after 1 loops
# S obs: 63.33535760175557
# Test stat reached after 1 loops
# S obs: 63.413714148205464
# Test stat reached after 1 loops
# S obs: 58.90532614185383
# Test stat reached after 1 loops
# S obs: 66.8620600626725
# Test stat reached after 1 loops
# S obs: 57.34754003136335
# Test stat reached after 1 loops
# S obs: 74.65722661012568
# Test stat reached after 1 loops
# S obs: 65.51415117727804
# Test stat reached after 1 loops
# S obs: 66.6712814744636
# Test stat reached after 1 loops
# S obs: 69.08278736811816
# Test stat reached after 1 loops
# S obs: 61.65473529883566
# Test stat reached after 1 loops
# S obs: 69.4595921877375
# Test stat reached after 1 loops
# S obs: 58.753786163618614
# Test stat reached after 1 loops
# S obs: 58.85028796820481
# Test stat reached after 1 loops
# S obs: 65.58501468972662
# Test stat reached after 1 loops
# S obs: 62.0562484933961
# Test stat reached after 1 loops
# S obs: 58.81164486180105
# Test stat reached after 1 loops
# S obs: 62.62543700086447
# Test stat reached after 1 loops
# S obs: 59.387591691403614
# Test stat reached after 1 loops
# S obs: 66.817058760895
# Test stat reached after 1 loops
# S obs: 75.36771476977715
# Test stat reached after 1 loops
# S obs: 66.03616537038808
# Test stat reached after 1 loops
# S obs: 58.80847346462057
# Test stat reached after 1 loops
# S obs: 68.50390320987741
# Test stat reached after 1 loops
# S obs: 54.03574739042997
# Test stat reached after 1 loops
# S obs: 60.86277016815948
# Test stat reached after 1 loops
# S obs: 64.39923965519195
# Test stat reached after 1 loops
# S obs: 54.04769012883789
# Test stat reached after 1 loops
# S obs: 64.54456718622531
# Test stat reached after 1 loops
# S obs: 63.033058583345216
# Test stat reached after 1 loops
# S obs: 77.67730104717546
# Test stat reached after 2 loops
# S obs: 69.86236130948103
# Test stat reached after 1 loops
# S obs: 74.0551626788341
# Test stat reached after 1 loops
# S obs: 59.3874745146042
# Test stat reached after 1 loops
# S obs: 67.0997551200305
# Test stat reached after 1 loops
# S obs: 60.084274991993624
# Test stat reached after 1 loops
# S obs: 69.56622281932889
# Test stat reached after 1 loops
# S obs: 60.94736762974214
# Test stat reached after 1 loops
# S obs: 67.6666720880826
# Test stat reached after 1 loops
# S obs: 63.64178960939275
# Test stat reached after 1 loops
# S obs: 68.68190967340915
# Test stat reached after 1 loops
# S obs: 74.48563526987225
# Test stat reached after 1 loops
# S obs: 64.33267422602995
# Test stat reached after 1 loops
# S obs: 60.868698513014884
# Test stat reached after 1 loops
# S obs: 54.76198834072018
# Test stat reached after 1 loops
# S obs: 53.941097934162144
# Test stat reached after 1 loops
# S obs: 62.89285907140366
# Test stat reached after 1 loops
# S obs: 62.953880939381015
# Test stat reached after 1 loops
# S obs: 66.69098858900882
# Test stat reached after 1 loops
# S obs: 64.8147666386136
# Test stat reached after 1 loops
# S obs: 67.60414614870092
# Test stat reached after 1 loops
# S obs: 65.67383662283721
# Test stat reached after 1 loops
# S obs: 72.68378918875244
# Test stat reached after 1 loops
# S obs: 78.51342250402129
# Test stat reached after 5 loops
# S obs: 71.30265185824707
# Test stat reached after 1 loops
# S obs: 54.664421602388735
# Test stat reached after 1 loops
# S obs: 69.14577329486757
# Test stat reached after 1 loops
# S obs: 77.4498696887562
# Test stat reached after 3 loops
# S obs: 59.78967787024727
# Test stat reached after 1 loops
# S obs: 57.685681144703445
# Test stat reached after 1 loops
# S obs: 66.31271651275264
# Test stat reached after 1 loops
# S obs: 54.64887737703182
# Test stat reached after 1 loops
# S obs: 61.06034890063157
# Test stat reached after 1 loops
# S obs: 60.01993810440103
# Test stat reached after 1 loops
# S obs: 72.59565035826897
# Test stat reached after 1 loops
# S obs: 65.25525262652776
# Test stat reached after 1 loops
# S obs: 64.03531352346006
# Test stat reached after 1 loops
# xsec BSM 4.6e-01 pb
# S obs: 70.6113605658451
# Test stat reached after 1 loops
# S obs: 67.68928455474997
# Test stat reached after 1 loops
# S obs: 71.28279505511512
# Test stat reached after 1 loops
# S obs: 64.39118097031965
# Test stat reached after 1 loops
# S obs: 77.35800183129065
# Test stat reached after 2 loops
# S obs: 77.77753573747981
# Test stat reached after 2 loops
# S obs: 67.54068773444916
# Test stat reached after 1 loops
# S obs: 75.0544762274028
# Test stat reached after 1 loops
# S obs: 87.61940775978147
# 90000 0
# Increasing by a factor 5 the number of asymov per loop
# 590000 4
# 1090000 15
# 1590000 19
# 2090000 23
# Test stat reached after 53 loops
# S obs: 75.7659644810868
# Test stat reached after 1 loops
# S obs: 73.08021148681347
# Test stat reached after 1 loops
# S obs: 59.90095783806671
# Test stat reached after 1 loops
# S obs: 75.26331271733697
# Test stat reached after 1 loops
# S obs: 61.95682830230725
# Test stat reached after 1 loops
# S obs: 68.54128274267144
# Test stat reached after 1 loops
# S obs: 71.32243161632309
# Test stat reached after 1 loops
# S obs: 60.1865428775106
# Test stat reached after 1 loops
# S obs: 60.7017252520342
# Test stat reached after 1 loops
# S obs: 70.25777115399931
# Test stat reached after 1 loops
# S obs: 69.9980459305722
# Test stat reached after 1 loops
# S obs: 68.08022487725363
# Test stat reached after 1 loops
# S obs: 65.24104200243698
# Test stat reached after 1 loops
# S obs: 62.69857519208447
# Test stat reached after 1 loops
# S obs: 69.96978245591362
# Test stat reached after 1 loops
# S obs: 74.67520092121606
# Test stat reached after 1 loops
# S obs: 78.72650869706474
# Test stat reached after 3 loops
# S obs: 65.4682318600732
# Test stat reached after 1 loops
# S obs: 55.675327461590804
# Test stat reached after 1 loops
# S obs: 90.68525330859994
# 90000 0
# Increasing by a factor 5 the number of asymov per loop
# 590000 0
# 1090000 4
# 1590000 4
# 2090000 4
# 2590000 7
# 3090000 7
# 3590000 7
# 4090000 8
# 4590000 8
# 5090000 9
# 5590000 9
# 6090000 10
# 6590000 10
# 7090000 10
# 7590000 12
# 8090000 12
# 8590000 12
# 9090000 13
# 9590000 13
# 10090000 13
# 10590000 14
# 11090000 16
# 11590000 17
# 12090000 17
# 12590000 18
# 13090000 18
# 13590000 18
# 14090000 19
# 14590000 21
# 15090000 21
# 15590000 21
# 16090000 22
# 16590000 23
# 17090000 24
# 17590000 24
# 18090000 24
# 18590000 24
# Test stat reached after 388 loops
# S obs: 72.3790784740338
# Test stat reached after 1 loops
# S obs: 61.000492569152904
# Test stat reached after 1 loops
# S obs: 64.91318836319398
# Test stat reached after 1 loops
# S obs: 82.15756734051112
# 90000 14
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 11 loops
# S obs: 83.66803297905714
# 90000 2
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 16 loops
# S obs: 63.73680565729372
# Test stat reached after 1 loops
# S obs: 74.26955790321472
# Test stat reached after 1 loops
# S obs: 64.13604358247436
# Test stat reached after 1 loops
# S obs: 67.18434775474446
# Test stat reached after 1 loops
# S obs: 64.12176364231149
# Test stat reached after 1 loops
# S obs: 59.79768166370935
# Test stat reached after 1 loops
# S obs: 62.72189909071174
# Test stat reached after 1 loops
# S obs: 57.71764631812178
# Test stat reached after 1 loops
# S obs: 68.26438254003422
# Test stat reached after 1 loops
# S obs: 72.78609279058456
# Test stat reached after 1 loops
# S obs: 59.26461951289407
# Test stat reached after 1 loops
# S obs: 69.78869467108512
# Test stat reached after 1 loops
# S obs: 55.40466675347392
# Test stat reached after 1 loops
# S obs: 62.73659813144219
# Test stat reached after 1 loops
# S obs: 75.12011695444777
# Test stat reached after 1 loops
# S obs: 72.12862902722748
# Test stat reached after 1 loops
# S obs: 67.23842006732691
# Test stat reached after 1 loops
# S obs: 59.39212841307887
# Test stat reached after 1 loops
# S obs: 69.64475062551266
# Test stat reached after 1 loops
# S obs: 81.79644683364008
# 90000 17
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 11 loops
# S obs: 63.4227312319416
# Test stat reached after 1 loops
# S obs: 66.39677654971882
# Test stat reached after 1 loops
# S obs: 69.84666692872021
# Test stat reached after 1 loops
# S obs: 50.494635717507435
# Test stat reached after 1 loops
# S obs: 65.30294659907868
# Test stat reached after 1 loops
# S obs: 71.03659964860944
# Test stat reached after 1 loops
# S obs: 66.149164557367
# Test stat reached after 1 loops
# S obs: 69.81227471770842
# Test stat reached after 1 loops
# S obs: 74.57479071668429
# Test stat reached after 1 loops
# S obs: 53.802943573367735
# Test stat reached after 1 loops
# S obs: 81.60508792237304
# 90000 17
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 10 loops
# S obs: 63.85966182492669
# Test stat reached after 1 loops
# S obs: 74.74512397694957
# Test stat reached after 1 loops
# S obs: 67.25955220133524
# Test stat reached after 1 loops
# S obs: 66.88021886848263
# Test stat reached after 1 loops
# S obs: 64.98720157875638
# Test stat reached after 1 loops
# S obs: 73.57568441823001
# Test stat reached after 1 loops
# S obs: 56.04208231264767
# Test stat reached after 1 loops
# S obs: 61.447050031366324
# Test stat reached after 1 loops
# S obs: 67.68435889566986
# Test stat reached after 1 loops
# S obs: 63.37721846350242
# Test stat reached after 1 loops
# S obs: 59.49110992473642
# Test stat reached after 1 loops
# S obs: 60.96667559067969
# Test stat reached after 1 loops
# S obs: 84.97112330719025
# 90000 4
# Increasing by a factor 5 the number of asymov per loop
# 590000 21
# Test stat reached after 21 loops
# S obs: 73.9982506490245
# Test stat reached after 1 loops
# S obs: 71.68664249880688
# Test stat reached after 1 loops
# S obs: 68.36641515316929
# Test stat reached after 1 loops
# S obs: 67.13380302764004
# Test stat reached after 1 loops
# S obs: 64.23051443263603
# Test stat reached after 1 loops
# S obs: 72.9254208011648
# Test stat reached after 1 loops
# S obs: 62.05809371639534
# Test stat reached after 1 loops
# S obs: 66.91004799864311
# Test stat reached after 1 loops
# S obs: 73.53950154002929
# Test stat reached after 1 loops
# S obs: 68.39982902758238
# Test stat reached after 1 loops
# S obs: 65.02257427962495
# Test stat reached after 1 loops
# S obs: 60.662868570674846
# Test stat reached after 1 loops
# S obs: 69.26713165572899
# Test stat reached after 1 loops
# S obs: 74.34798444786487
# Test stat reached after 1 loops
# S obs: 72.46161927451263
# Test stat reached after 1 loops
# S obs: 71.27782633801276
# Test stat reached after 1 loops
# S obs: 78.85498015665225
# Test stat reached after 4 loops
# S obs: 72.56243565931544
# Test stat reached after 1 loops
# S obs: 69.88974328656714
# Test stat reached after 1 loops
# S obs: 62.6509221662751
# Test stat reached after 1 loops
# S obs: 61.19345374660815
# Test stat reached after 1 loops
# S obs: 64.568325261712
# Test stat reached after 1 loops
# xsec BSM 1.0e+00 pb
# S obs: 78.78048137986943
# Test stat reached after 2 loops
# S obs: 74.86631327085621
# Test stat reached after 1 loops
# S obs: 85.55646745713678
# 90000 6
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 19 loops
# S obs: 70.65990404635437
# Test stat reached after 1 loops
# S obs: 71.10035225971866
# Test stat reached after 1 loops
# S obs: 78.16980887825028
# Test stat reached after 2 loops
# S obs: 80.4770200885084
# Test stat reached after 7 loops
# S obs: 75.35431888379
# Test stat reached after 1 loops
# S obs: 68.46402710344668
# Test stat reached after 1 loops
# S obs: 75.15406430970421
# Test stat reached after 1 loops
# S obs: 84.16449600409327
# 90000 12
# Increasing by a factor 5 the number of asymov per loop
# Test stat reached after 12 loops
# S obs: 72.3183095918505
# Test stat reached after 1 loops
# S obs: 72.02645869665027
# Test stat reached after 1 loops
# S obs: 82.06903874805681
# Test stat reached after 9 loops
# S obs: 67.96206620985937
# Test stat reached after 1 loops
# S obs: 73.97554297132491
# Test stat reached after 1 loops
# S obs: 65.72580983589215
# Test stat reached after 1 loops
# S obs: 71.48904070858548
# Test stat reached after 1 loops
# S obs: 80.46204923293908
# Test stat reached after 5 loops
# S obs: 76.40536156104066
# Test stat reached after 1 loops
# S obs: 73.87723134637857
# Test stat reached after 1 loops
# S obs: 87.97860024445545
# 90000 2
# Increasing by a factor 5 the number of asymov per loop
# 590000 8
# 1090000 13
# 1590000 18
# Test stat reached after 47 loops
# S obs: 74.4188859019159
# Test stat reached after 1 loops
# S obs: 80.31626313510684
# Test stat reached after 3 loops
# S obs: 70.36885633167479
# Test stat reached after 1 loops
# S obs: 78.30259667990669
# Test stat reached after 2 loops
# S obs: 77.05257772496692
# Test stat reached after 2 loops
# S obs: 68.21366560397162
# Test stat reached after 1 loops
# S obs: 82.0623282983964
# Test stat reached after 8 loops
# S obs: 75.11861997172267
# Test stat reached after 1 loops
# S obs: 77.41560123626415
# Test stat reached after 1 loops
# S obs: 69.52870454513665
# Test stat reached after 1 loops
# S obs: 80.02825308667339
# Test stat reached after 6 loops
# S obs: 87.3533023833414
# 90000 1
# Increasing by a factor 5 the number of asymov per loop
# 590000 15

# %% [markdown]
# # Make the p-value plot

# %%
sample_col = {
              'AtoZZZ':'r',
              'GtoWW':'b',
              'GtoBtt':'g',
              'GtoNtt':'c'
             }

# %%
matplotlib.rcParams.update({'font.size': 18})
fig, ax1 = plt.subplots(figsize=(8,8))

for n, val_aux in dic_p_val.iteritems():
    val_aux = np.array(val_aux)
    x_sec = val_aux[:, 0]
    quant = val_aux[:, 1:]
    
    ax1.plot(x_sec, quant[:, 2], color=sample_col[n], label=sample_label[n])
    ax1.fill_between(x_sec, quant[:, 1], quant[:, 3], color=sample_col[n], alpha = 0.3, lw=0)
#     ax1.fill_between(x_sec, quant[:, 0], quant[:, 4], color=sample_col[n], alpha = 0.1, lw=0)
    
    
plt.xscale('log')
plt.xlabel('Cross section [pb]')
plt.yscale('log')
plt.ylabel('p-value')
plt.ylim(1 - erf(5.5/np.sqrt(2)), 1)
plt.legend(loc='upper right')
ax2 = ax1.twinx()
for i in range(1, 6):
    p = 1 - erf(i/np.sqrt(2))
    ax2.plot([x_sec[0], x_sec[-1]], 2*[p], '--', color='grey')
plt.yscale('log')
ax2.set_yticks(1 - erf(np.arange(1,6)/np.sqrt(2)))
ax2.set_yticklabels(['{}$\sigma$'.format(i) for i in range(1,6)])
ax2.tick_params(axis='y', labelcolor='grey')

fig.savefig('../fig/ModelIndependentAnalysis/' + 'pValueScan_L' + str(lumi) + 'pb-1.png')
